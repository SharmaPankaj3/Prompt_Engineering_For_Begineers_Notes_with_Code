# %% [markdown]
# # Iterative Prompt Development
# In this lesson, you'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.
#
# ## Setup

# %%
from openai import OpenAI

# Read API key from text file
with open(r"D:\desktop\Pankaj_New_OpenAI_Key.txt", "r") as file:
    OPENAI_API_KEY = file.read().strip()

# Create OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    response = client.responses.create(
        model=model,
        input=prompt,
        temperature=0 # this is the degree of randomness of the model's output
    )
    return response.output_text

# %% [markdown]
# **Note**: In June 2023, OpenAI updated gpt-3.5-turbo. The results you see in the notebook may be slightly different than those in the video. Some of the prompts have also been slightly modified to product the desired results.

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt_1 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_1)
print(response)
# Out:
# Introducing the SWC-100 Office Chair - a stylish and versatile addition to any workspace.
#
# Part of a sophisticated mid-century inspired furniture collection, this chair is designed to elevate your office environment with its sleek and modern aesthetic. Choose from a variety of shell colors and base finishes to customize the look to suit your taste and decor.
#
# The SWC-100 Office Chair offers two upholstery options: plastic back and front upholstery for a contemporary feel, or full upholstery for added comfort and luxury. With a range of fabric and leather choices, you can create a chair that reflects your personal style.
#
# Constructed with a durable 5-wheel plastic coated aluminum base, this chair is not only stylish but also functional. The pneumatic chair adjust feature allows for easy height adjustment, ensuring optimal comfort for long hours of work.
#
# Designed for both home and business settings, this chair is suitable for a variety of environments. Whether you prefer a chair with or without armrests, the SWC-100 Office Chair provides versatility to meet your needs.
#
# With its quality construction and materials, including a sturdy aluminum shell and high-density foam seat, this chair is built to last. Choose between soft or hard-floor casters, two seat foam densities, and armless or PU armrest options for a chair that is tailored to your preferences.
#
# Elevate your workspace with the SWC-100 Office Chair, designed and crafted in Italy to bring a touch of elegance and functionality to your office. Experience the perfect blend of style and comfort with this exceptional piece of furniture.

# %%
len(response.split())
# Out:
# 255

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt_2 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_2)
print(response)
# Out:
# Introducing our versatile mid-century office chair, designed for both style and comfort. Choose from a range of colors and finishes to suit your space. With adjustable height and optional armrests, this chair is perfect for home or office use. Made in Italy with quality materials for durability.

# %%
len(response.split())
# Out:
# 47

# %%
prompt_3 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 3 sentences.

Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_3)
print(response)
# Out:
# Introducing our versatile and stylish mid-century inspired office chair, perfect for both home and business environments. With a range of customizable options including shell color, base finishes, and upholstery choices in fabric or leather, this chair offers both comfort and sophistication. Constructed with a durable aluminum base and featuring pneumatic chair adjustment, this Italian-made chair combines functionality with modern design.

# %%
prompt_4 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 280 characters.

Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_4)
print(response)
# Out:
# Introducing our versatile mid-century inspired office chair! With customizable options in color, upholstery, and base finish, this chair is perfect for both home and business use. Featuring a durable construction with pneumatic adjustment for comfort. Made in Italy.

# %%
len(response)
# Out:
# 266

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt_5 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 100 words.

Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_5)
print(response)
# Out:
# Introducing our versatile and stylish office chair, part of a sophisticated mid-century inspired furniture collection. Crafted with precision and quality in mind, this chair offers a range of customization options to suit any decor. The durable construction features a 5-wheel plastic coated aluminum base for stability and mobility, while the pneumatic chair adjustment ensures effortless height control. The seat is designed for comfort with HD36 foam, and the shell base glider is made of cast aluminum with a modified nylon coating. Elevate your workspace with this Italian-made chair, perfect for both home and professional environments.

# %%
prompt_6 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_6)
print(response)
# Out:
# Introducing our versatile office chair, part of a stylish mid-century collection. Choose from various shell colors and base finishes to suit your space. Constructed with a durable aluminum base and high-density foam seat for comfort. Perfect for home or office use. Product IDs: SWC-100, SWC-110.

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt_7 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_7)
print(response)
# Out:
# ```html
# <div>
#     <p>This mid-century inspired office chair is a perfect blend of style and functionality. Constructed with high-quality materials, the chair features a durable shell base glider made of cast aluminum with a modified nylon PA6/PA66 coating, ensuring longevity and stability. The seat is crafted with HD36 foam, providing both comfort and support for long hours of use. Available in various shell colors and base finishes, this chair is a versatile addition to any home or business setting.</p>
#
#     <p>The chair is designed with a 5-wheel plastic coated aluminum base for smooth mobility and a pneumatic adjustment for easy height customization. With options for different upholstery materials, base finishes, and armrest configurations, this chair can be tailored to suit individual preferences and needs. Whether for a modern office space or a cozy home office, this chair is a stylish and practical choice.</p>
#
#     <p>Product IDs: SWC-100, SWC-110</p>
#
#     <h2>Product Dimensions</h2>
#     <table>
#         <tr>
#             <td>WIDTH</td>
#             <td>20.87"</td>
#         </tr>
#         <tr>
#             <td>DEPTH</td>
#             <td>20.08"</td>
#         </tr>
#         <tr>
#             <td>HEIGHT</td>
#             <td>31.50"</td>
#         </tr>
#         <tr>
#             <td>SEAT HEIGHT</td>
#             <td>17.32"</td>
#         </tr>
#         <tr>
#             <td>SEAT DEPTH</td>
#             <td>16.14"</td>
#         </tr>
#     </table>
# </div>
# ```

# %% [markdown]
# ## Load Python libraries to view HTML

# %%
from IPython.display import display, HTML,Markdown

# %%
display(HTML(response))
# Out:
# ```html
# <div>
#     <p>This mid-century inspired office chair is a perfect blend of style and functionality. Constructed with high-quality materials, the chair features a durable shell base glider made of cast aluminum with a modified nylon PA6/PA66 coating, ensuring longevity and stability. The seat is crafted with HD36 foam, providing both comfort and support for long hours of use. Available in various shell colors and base finishes, this chair is a versatile addition to any home or business setting.</p>
#
#     <p>The chair is designed with a 5-wheel plastic coated aluminum base for smooth mobility and a pneumatic adjustment for easy height customization. With options for different upholstery materials, base finishes, and armrest configurations, this chair can be tailored to suit individual preferences and needs. Whether for a modern office space or a cozy home office, this chair is a stylish and practical choice.</p>
#
#     <p>Product IDs: SWC-100, SWC-110</p>
#
#     <h2>Product Dimensions</h2>
#     <table>
#         <tr>
#             <td>WIDTH</td>
#             <td>20.87"</td>
#         </tr>
#         <tr>
#             <td>DEPTH</td>
#             <td>20.08"</td>
#         </tr>
#         <tr>
#             <td>HEIGHT</td>
#             <td>31.50"</td>
#         </tr>
#         <tr>
#             <td>SEAT HEIGHT</td>
#             <td>17.32"</td>
#         </tr>
#         <tr>
#             <td>SEAT DEPTH</td>
#             <td>16.14"</td>
#         </tr>
#     </table>
# </div>
# ```

# %%
prompt_8 = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as Markdown that can be used in a website. 


Technical specifications: ```{fact_sheet_chair}```
"""

# %%
response = get_completion(prompt_8)
print(response)
# Out:
# Introducing our latest addition to the mid-century inspired office furniture collection - the versatile and stylish office chair designed to elevate any workspace. Crafted with meticulous attention to detail, this chair offers a perfect blend of form and function.
#
# The chair features a durable construction with a 5-wheel plastic coated aluminum base, ensuring stability and mobility. The pneumatic chair adjustment allows for easy raise and lower action, providing personalized comfort throughout the day.
#
# Customize your chair with a choice of shell colors and base finishes to suit your aesthetic preferences. Opt for the plastic back and front upholstery or indulge in the luxurious full upholstery available in a variety of fabric and leather options. Choose between different base finish options including stainless steel, matte black, gloss white, or chrome. Select whether you prefer the chair with or without armrests, catering to your specific needs.
#
# Designed for both home and business settings, this chair is qualified for contract use, making it a versatile and practical choice for any environment.
#
# **Product IDs:** SWC-100, SWC-110
#
# ### Product Dimensions
# | Dimension    | Measurement |
# |--------------|-------------|
# | WIDTH        | 20.87"      |
# | DEPTH        | 20.08"      |
# | HEIGHT       | 31.50"      |
# | SEAT HEIGHT  | 17.32"      |
# | SEAT DEPTH   | 16.14"      |
#
# Enhance your workspace with this Italian-crafted chair that combines style, comfort, and durability. Upgrade your office furniture with this premium piece that exudes sophistication and functionality.

# %%
display(Markdown(response))
# Out:
# Introducing our latest addition to the mid-century inspired office furniture collection - the versatile and stylish office chair designed to elevate any workspace. Crafted with meticulous attention to detail, this chair offers a perfect blend of form and function.
#
# The chair features a durable construction with a 5-wheel plastic coated aluminum base, ensuring stability and mobility. The pneumatic chair adjustment allows for easy raise and lower action, providing personalized comfort throughout the day.
#
# Customize your chair with a choice of shell colors and base finishes to suit your aesthetic preferences. Opt for the plastic back and front upholstery or indulge in the luxurious full upholstery available in a variety of fabric and leather options. Choose between different base finish options including stainless steel, matte black, gloss white, or chrome. Select whether you prefer the chair with or without armrests, catering to your specific needs.
#
# Designed for both home and business settings, this chair is qualified for contract use, making it a versatile and practical choice for any environment.
#
# **Product IDs:** SWC-100, SWC-110
#
# ### Product Dimensions
# | Dimension    | Measurement |
# |--------------|-------------|
# | WIDTH        | 20.87"      |
# | DEPTH        | 20.08"      |
# | HEIGHT       | 31.50"      |
# | SEAT HEIGHT  | 17.32"      |
# | SEAT DEPTH   | 16.14"      |
#
# Enhance your workspace with this Italian-crafted chair that combines style, comfort, and durability. Upgrade your office furniture with this premium piece that exudes sophistication and functionality.

# %% [markdown]
# ## Try experimenting on your own!
